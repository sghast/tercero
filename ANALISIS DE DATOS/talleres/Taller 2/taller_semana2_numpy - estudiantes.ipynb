# %% [markdown]
# # 🔬 Taller Práctico — Semana 2
#
# ## NumPy: Matrices Estructuradas, np.dot vs np.multiply y Medición de Tiempos
#
# ---
#
# | Campo          | Detalle                     |
# | -------------- | --------------------------- |
# | **Asignatura** | Análisis de Datos — TDSD353 |
# | **Semana**     | 2 — Período 2026-A          |
# | **Paralelo**   | GR2 — Martes 10:00–13:00    |
# | **Docente**    | Juan Carlos Gonzalez Ortiz  |
# | **Estudiante** | _(escribe tu nombre aquí)_  |
# | **Fecha**      | _(escribe la fecha aquí)_   |
#
# ---
#
# ## Objetivos
#
# Al finalizar este taller serás capaz de:
#
# 1. Construir matrices NumPy con **bordes y patrones estructurados** usando slicing.
# 2. Aplicar y distinguir **`np.dot`** (multiplicación matricial) vs **`np.multiply`** (Hadamard).
# 3. **Medir tiempos de ejecución** con `time.time()` y guardar resultados en archivos `.txt`.
#
# ---

# %% [markdown]
# ---
#
# ## Configuración inicial
#
# Ejecuta esta celda primero. Importa las librerías necesarias para todo el taller.

# %%
import numpy as np
import time

print(" Librerías importadas correctamente")

# %% [markdown]
# ---
#
# ## PARTE 1 — Construcción de Matrices Estructuradas
#
# Construir matrices con **bordes y patrones específicos** usando slicing de NumPy.
# El patrón es siempre el mismo:
#
# 1. Crear la **base** (zeros u ones)
# 2. Sobreescribir los **bordes** con slicing

# %% [markdown]
# ### Actividad 1 — Matriz M1: Bordes Aleatorios, Interior = 0(1 pt)
#
# **Objetivo:** Crear una matriz 10×10 donde los **cuatro bordes tienen valores aleatorios** (1–10) y el **interior es cero**.
#
# ![Imagen referencial](https://i.imgur.com/trLQFG2.png)

# %%
dim = (10, 10)

# PASO 1: Crear base de ceros


# PASO 2: Generar valores aleatorios para los bordes


# PASO 3: Asignar los cuatro bordes con slicing

# %% [markdown]
# **Reflexión A1:** ¿Qué pasa si usas `M1[1:-1, 1:-1]`? ¿Qué parte de la matriz accede?

# %% [markdown]
# ---
#
# ### Actividad 2 — Matriz M2: Bordes = 0, Interior Aleatorio(1 pt)
#
# **Objetivo:** Crear la matriz **inversa a M1**: ahora el interior tiene valores aleatorios y los bordes son cero.
# ![Imagen referencial](https://i.imgur.com/RiwlS39.png[/img])

# %%
# PASO 1: Crear base con valores aleatorios en toda la matriz


# PASO 2: Sobreescribir los cuatro bordes con cero

# %% [markdown]
# Reto: No puntua, pero, como harias para hacer una matriz de ceros de (10x10) en donde solo en la diagonal van a ir numeros aleatorios?

# %% [markdown]
# ---
#
# ### ✏️ Actividad 3 — Inspección de Matrices(1 pt)
#
# Antes de operar, siempre debemos **verificar las propiedades** de nuestros arrays. Para M1 y M2, obten el shape, dtype, el size, valor minimo, valor maximo, y la sumatoria total

# %% [markdown]
# ---
#
# ## PARTE 2 — np.dot vs np.multiply

# %% [markdown]
# ### ✏️ Actividad 4 — Calcular M3 = np.dot(M1, M2) y obten el maximo y minimo valor de la matriz M3(1 pt)

# %% [markdown]
# ### ✏️ Actividad 5 — Calcular M4 = np.multiply(M1, M2) y obten el maximo y minimo valor de la matriz M3(1 pt)

# %% [markdown]
# ---
#
# ## PARTE 3 — Medición de Tiempos y Archivos .txt
#
# Usa `time.time()` para medir el costo computacional de cada operación y guardaremos los resultados en archivos de texto.
#
# **Patrón de medición:**
#
# ```python
# inicio = time.time()
# # ← operación a medir →
# fin = time.time()
# duracion = round((fin - inicio) * 1000, 5)  # en milisegundos
# ```

# %% [markdown]
# ### ✏️ Actividad 6 — Medir Tiempos de np.dot y np.multiply usando M1 y M2 e indicar cual fue más rapido(1 pt)

# %% [markdown]
# Con matrices 10×10 los tiempos son muy pequeños (microsegundos). Para ver diferencias más claras, ejecutemos con matrices más grandes. Crea una Matriz de datos aleatorios de 1000 x 1000 (un millón de elementos)(no uses semilla) y vuelve a calcular el tiempo y realizar el dot y multiply y compara tiempos

# %% [markdown]
# ---
#
# ### ✏️ Actividad 7 — Guardar el resultado de la actividad 6 en un archivo txt llamado resultado1.txt. En este archivo solo debe imprimirse en texto el tiempo que demoro la operacion multiply, el tiempo que demoro dot y la diferencia de tiempo que hubo entre estas dos operaciones.(1 pt)

# %% [markdown]
#  ### ✏️ Actividad 8-Guarda la matriz de un millon de datos en el formato .npy llamado resultado2.npy ya que es más rápido y ocupa menos espacio comparado con un txt.(1 pt)

# %% [markdown]
# ## Actividad 9. Historia de la UEFA Champions League
#
# Trabajarás con el **histórico completo de finales de la UEFA Champions League** desde su primera edición en 1956 hasta 2025. El archivo `champions_league.csv` contiene las siguientes columnas:
#
# | Columna | Tipo | Descripción |
# |---|---|---|
# | `Anio` | numérico | Año de la final |
# | `Campeon` | texto | Club campeón |
# | `Finalista` | texto | Club subcampeón |
# | `Goles_campeon` | numérico | Goles del campeón en la final |
# | `Goles_finalista` | numérico | Goles del finalista en la final |
# | `Asistencia` | numérico | Espectadores en el estadio |
# | `Pais_campeon` | texto | País del club campeón |
#
# > ⚠️ El dataset contiene **datos faltantes** en algunas columnas numéricas. Parte de los ejercicios consiste en identificarlos y manejarlos correctamente.
#
# ---
#
# **Instrucciones generales:**
# - Completa cada celda donde aparezca `# TU CÓDIGO AQUÍ` y donde veas ... (3 puntos seguidos)
# - Trabaja en orden: cada parte puede depender de las anteriores.
# - Coloca `champions_league.csv` en la misma carpeta que este cuaderno.
#
# ---
# ## PARTE 4 — Importación de Datos
#
# ### Ejercicio 9.1 — Cargar el dataset numérico(1 pt)
#
# Usa `np.genfromtxt()` para leer el archivo `champions_league.csv` y cargar **únicamente las columnas numéricas** en un array llamado `datos`.
#
# Las columnas numéricas y sus índices en el CSV son:
#
# | Índice CSV | Columna |
# |:---:|---|
# | 0 | `Anio` |
# | 3 | `Goles_campeon` |
# | 4 | `Goles_finalista` |
# | 5 | `Asistencia` |
#
# Usa `dtype=float` para que las celdas vacías queden como `np.nan`.

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 1.2 — Cargar los nombres de los campeones(1 pt)
#
# Crea un array separado llamado `campeones` que contenga **solo la columna de texto `Campeon`** (columna índice 1 del CSV), cargada como tipo `str`.
#
# > 💡 Usa `dtype=str` y `usecols=(1,)` en `genfromtxt()`.

# %%
#Aquí debes leer solo la columna de texto Campeon del CSV.
# TU CÓDIGO AQUÍ

# %% [markdown]
# ---
# ## PARTE 5 — Tratamiento de Datos Faltantes
#
# ### Ejercicio 2.1 — Diagnóstico de NaN(1 pt)
#
# Determina:
#
# a) ¿Cuántos valores `NaN` hay en total en el array `datos`?
# b) ¿Cuántos `NaN` hay en cada columna?
# c) ¿En qué años hay datos faltantes? Filtra las filas con NaN y muestra sus años.

# %% [markdown]
# ### Ejercicio 9.2 — Imputar datos faltantes(1 pt)
#
# 9.2.1 .Crea una copia del array llamada `datos_limpios` donde:
# - Los `NaN` en `Goles_campeon` (col 1) se reemplacen por la **mediana** de esa columna.
# - Los `NaN` en `Goles_finalista` (col 2) se reemplacen por la **mediana** de esa columna.
# - Los `NaN` en `Asistencia` (col 3) se reemplacen por el **promedio** de esa columna.
#
# > 💡 Usa `np.nanmedian()`, `np.nanmean()` y `np.where()`.

# %% [markdown]
# 9.2.2 Ejercicio  ( 1 pt)
# Consulta sobre .npz en numpy y mandar a guardar datos_limpios en formato .csv incluyendo las cabeceras de cada columna y los datos

# %% [markdown]
# ---
# ## ✅ Checklist de Entrega
#
# Antes de enviar tu notebook, verifica que:
#
# - [ ] El encabezado tiene tu nombre y fecha
# - [ ] Todas las celdas de código se ejecutaron sin error (`Kernel > Restart & Run All`)
#
#
# ---
#
# **Entregable:** Este archivo `.ipynb` con todas las celdas ejecutadas + los archivos que se deben generar
#
# > _Docente: Juan Carlos Gonzalez Ortiz — TDSD353 Análisis de Datos — ESFOT-EPN 2026-A
